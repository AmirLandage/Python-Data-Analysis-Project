# %%
import pandas as pd

# %%
data = pd.read_csv(r"X:\Data Science\Projects\Python\Udemy\7. Udemy Courses.csv")

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
# What are the study level and number of courses

# %%
data.level.value_counts()
# Out:
# All Levels            1932
# Beginner Level        1271
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
# what are the different subject that Udemy is offering courses?

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
# How many courses eacch subject contains ?

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
# Show all the courses which are free of cost

# %%
data[data.is_paid == False]

# %%
# show all the courses that are paid

# %%
table1 = data[data.is_paid == 'True']
table1.to_csv('out1.csv')

# %%
# Find out the lowest selling courses

# %%
data.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title is_paid  \
# 649     1233314                      Building a Balanced Scorecard    True
# 3259    1232282          The Cash Flow Statement - An Introduction    True
# 3261    1275872                    The Complete Adobe Spark Course    True
# 910      726314       Create Beautiful Image Maps for Your Website    True
# 3328     715476        The Cuckoo Strategy to get European Funding    True
# ...         ...                                                ...     ...
# 3316     764164              The Complete Web Developer Course 2.0    True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    True
# 3385     625204                         The Web Developer Bootcamp    True
# 776       59014                     Coding for Entrepreneurs Basic    True
# 2230      41295               Learn HTML5 Programming From Scratch    True
#
# ...

# %%
# find out the highest selling courses

# %%
data.sort_values('num_subscribers', ascending = False)
# Out:
#       course_id                                       course_title is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    True
# 776       59014                     Coding for Entrepreneurs Basic    True
# 3385     625204                         The Web Developer Bootcamp    True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    True
# 3316     764164              The Complete Web Developer Course 2.0    True
# ...         ...                                                ...     ...
# 2290    1223240  Learn Pirates of the Caribbean by Ear on the P...    True
# 1267    1258666                Financial Statement Auditing Cycles    True
# 2070    1215926                Kickstarter success in 5 easy steps    True
# 1931    1247992  Introduction to Project Management for Finance...    True
# 3165    1087466  Stop Creditors from Harassing you and Avoid Ba...    True
#
# ...

# %%
# Show all the courses of the Graphic Design where the price is below 100

# %%
data[(data.subject == 'Graphic Design') & (data.price < '100')]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
# there aare no courese for graphic design below $100 price

# %%
# show all the cpurese of the graphic design which price is $100

# %%
data[(data.subject == 'Graphic Design') & (data.price == '100')]
# Out:
#       course_id                                       course_title is_paid  \
# 11        64605                                         1 Hour CSS    True
# 14        72262                                      1 hour jQuery    True
# 47      1269190          7 Secrets To Designing In Black and White    True
# 50       665042  8 Beautiful Ruby on Rails Apps in 30 Days & TD...    True
# 135      262370      Accounting: Get Hired Without Work Experience    True
# ...         ...                                                ...     ...
# 3572     542254               Web Programming Course : Asp.Net MVC    True
# 3594     908664  Word Swag : Create Stunning Images with the Wo...    True
# 3613     384318  WordPress for Beginners - Build Your First Web...    True
# 3645    1271430        Workshop on Banking Credit Analysis Process    True
# 3670     560996  You can create Incredible Websites with HTML C...    True
#
# ...

# %%
# find out the corses which are related with python

# %%
data[data.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...    True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...    True
# 814      631128  Complete Python Web Course: Build 8 Python Web...    True
# 842      186096  Core: A Web App Reference Guide for Django, Py...    True
# 1400     394832  Fun and creative web engineering with Python a...    True
# 1932    1038538            Introduction to QGIS Python Programming    True
# 1969     902888          Investment Portfolio Analysis with Python    True
# 2294     391546        Learn Python and Django: Payment Processing    True
# 2295    1063722            Learn Python Django - A Hands-On Course    True
# 2341     546848  Learn to code in Python and learn Adobe Photos...    True
# 2906     368340    Professional Python Web Development Using Flask    True
# ...

# %%
len(data[data.course_title.str.contains('Python')])
# Out:
# 29

# %%
# there are total 29 courses which are related to Python

# %%
# What are the courses that published in year 2015

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                object
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data['published_timestamp'] = pd.to_datetime(data.published_timestamp) 
# converting the object data type into the datetime data type

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                             object
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data['Year'] = data['published_timestamp'].dt.year
# the new column had been created for year

# %%
data.head()
# Out:
#    course_id                                       course_title is_paid price  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...    True    35
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...    True    75
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...    True    75
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...    True    75
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...    True    75
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             3137           18            68          All Levels
# 1             1593            1            41  Intermediate Level
# 2              482            1            47  Intermediate Level
# 3              850            3            43  Intermediate Level
# 4              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp         subject  Year
# ...

# %%
data[data.Year == 2015]
# It shows that all the courses that are published in the year 2015
# Out:
#       course_id                                       course_title is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...    True
# 16       302450        10 Numbers Every Business Owner Should Know    True
# 19       384928  101 Blues riffs - learn how the harmonica supe...    True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...    True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps    True
# ...         ...                                                ...     ...
# 3675     551170                         Your First Course on Piano    True
# 3676     498488  Your First Successful Forex Trades - With Case...    True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...    True
# 3678     552700    Your Second Course on Piano: Two Handed Playing    True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...    True
#
# ...

# %%
# What are the Max number of Subscribers for each level of course ?

# %%
data.groupby('level')

# %%
data.groupby('level')['num_subscribers']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data.groupby('level')['num_subscribers']
#
# NameError: name 'data' is not defined

# %%
# find out number of courses bublished each year

# %%
data.Year.value_counts()
# Out:
# 2016    1206
# 2015    1014
# 2017     719
# 2014     491
# 2013     202
# 2012      45
# 2011       5
# Name: Year, dtype: int64
